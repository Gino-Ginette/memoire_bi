# %% [markdown]
# # ÉTAPE 1 : CHARGEMENT DES DONNÉES
# # On importe les deux fichiers Excel dans Python
# # pandas est la bibliothèque qui permet de manipuler les tableaux

# %%
import pandas as pd   # "pd" est un raccourci qu'on utilisera partout

# Afficher toutes les colonnes sur une seule ligne
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1100)
pd.set_option('display.max_colwidth', 15)

# Chargement du fichier des commandes
df_commandes = pd.read_excel("commande_produit_blanc_2017_2025.xlsx")

# Chargement du fichier des stations
df_stations = pd.read_excel("liste des station.xlsx")

print("Commandes:", df_commandes.shape)
print(df_commandes.head(5))

print("\nStations:", df_stations.shape)
print(df_stations.head(5))
# Out:
# Commandes: (51853, 13)
#   Date comptabilisation N° document N° article N° origine N° contact origine  Quantité facturée  Montant vente (réel)  Coût total (réel) Code Produit Type écriture   Type document Code magasin N° commande
# 0      2017-02-03          BL170352      A0001      C0437             NaN            -4000.0          1591724.0            -1420103.0      PROD-BLANC         Vente  Expédition ...         ORYX         NaN
# 1      2017-02-03          BL170352      A0002      C0437             NaN            -4000.0          1568818.0                   0.0      PROD-BLANC         Vente  Expédition ...         ORYX         NaN
# 2      2017-02-03          BL170353      A0001      C0001             NaN            -3000.0          1202793.0            -1065077.0      PROD-BLANC         Vente  Expédition ...         ORYX         NaN
# ...

# %% [markdown]
# ## ÉTAPE 2 : FUSION DES DEUX FICHIERS
# # On relie les commandes aux stations via le code client
# # Colonne clé : "N° origine" (commandes) = "Code Contact Client" (stations)

# %%
df = pd.merge(
    df_commandes,                            # fichier principal : les commandes
    df_stations,                             # fichier secondaire : les stations
    left_on="N° contact origine",            # colonne de jointure dans commandes
    right_on="Code_sous_compte_Client",      # colonne de jointure dans stations
    how="left"                               # on garde TOUTES les commandes
)

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', 15)

print("Nombre de lignes après fusion :", df.shape[0])
print("Nombre de colonnes après fusion :", df.shape[1])
print()
print(df[["Date comptabilisation", "N° contact origine", "NOM CLIENT", 
          "Code Station", "Quantité facturée"]].head(5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.merge(
#       2     df_commandes,           # fichier principal : les commandes
#       3     df_stations,            # fichier secondaire : les stations
#       4     left_on="N° contact origine",   # colonne de jointure dans commandes
#       5     right_on="Code Contact Client",  # colonne de jointure dans stations
#       6     how="left"              # "left" = on garde TOUTES les commandes
#       7                             # même si la station n'est pas trouvée
#       8 )
#       9 # Afficher toutes les colonnes sur une seule ligne
#      10 pd.set_option('display.max_columns', None)
#
# NameError: name 'pd' is not defined

# %%
##ÉTAPE 3 : NETTOYAGE DES DONNÉES
# Avant toute analyse, on vérifie et corrige la qualité des données

# %%
# --- 3.1 Convertir la date en format datetime ---
df["Date comptabilisation"] = pd.to_datetime(df["Date comptabilisation"])

# --- 3.2 Vérifier les valeurs manquantes ---
print("=== Valeurs manquantes par colonne ===")
print(df.isnull().sum())
print()

# --- 3.3 Garder uniquement les commandes avec une station identifiée ---
df_clean = df.dropna(subset=["Code Station"]).copy()  # .copy() évite le warning
print("Lignes avant nettoyage :", df.shape[0])
print("Lignes après nettoyage :", df_clean.shape[0])
print("Lignes supprimées :", df.shape[0] - df_clean.shape[0])
print()

# --- 3.4 Corriger les quantités négatives ---
df_clean["Quantité facturée"] = df_clean["Quantité facturée"].abs()

print("=== Vérification des quantités après correction ===")
print(df_clean["Quantité facturée"].describe())
# Out:
# === Valeurs manquantes par colonne ===
# Date comptabilisation          0
# N° document                    0
# N° article                     0
# N° origine                     0
# N° contact origine         15811
# Quantité facturée              0
# Montant vente (réel)           0
# Coût total (réel)              0
# Code Produit                   0
# Type écriture                  0
# Type document                  0
# Code magasin                   0
# N° commande                10846
# Code Contact Client         6966
# NOM CLIENT                  6966
# Code_sous_compte_Client     6966
# Nom sous compte             6966
# TYPE                        6966
# STATUT                      6966
# Code Station                6966
# GROUPE TYPE                 6966
# dtype: int64
#
# Lignes avant nettoyage : 79890
# Lignes après nettoyage : 72924
# Lignes supprimées : 6966
#
# === Vérification des quantités après correction ===
# count    72924.000000
# mean      7804.774419
# ...

# %%
# ============================================================
##ÉTAPE 4 : SUPPRESSION DES COLONNES INUTILES
# On garde uniquement les colonnes utiles pour la prédiction
# ============================================================

# %%
colonnes_a_supprimer = [
    "N° document",
    "Montant vente (réel)",
    "Coût total (réel)",
    "Type écriture",
    "Code magasin",
    "Code_sous_compte_Client",
    "Code Contact Client",
    "N° commande"
]

df_clean = df_clean.drop(columns=colonnes_a_supprimer, errors="ignore")

# Vérification
print("Colonnes restantes :")
for col in df_clean.columns:
    print(" -", col)

print()
print("Dimensions finales :", df_clean.shape)
# Out:
# Colonnes restantes :
#  - Date comptabilisation
#  - N° article
#  - N° origine
#  - N° contact origine
#  - Quantité facturée
#  - Code Produit
#  - Type document
#  - NOM CLIENT
#  - Nom sous compte
#  - TYPE
#  - STATUT
#  - Code Station
#  - GROUPE TYPE
#
# Dimensions finales : (72924, 13)

# %%
#affichage du resultat
print(df_stations.head(5))
# Out:
#   Code Contact Client                           NOM CLIENT  \
# 0               C0083                          2M ASSOCIES
# 1               C0083                          2M ASSOCIES
# 2               C0438                            ABBE SOLO
# 3               C2472                          ADOUNI PLUS
# 4               C2241  ADOUNI PLUS SARL (NE PLUS UTILISER)
#
#   Code_sous_compte_Client               Nom sous compte  TYPE         STATUT  \
# 0                  CC6471      STATION BOULEVARD MARINA  CODO  Fonctionnelle
# 1                  CC3018  STATION COMMISSARIAT CENTRAL  CODO  Fonctionnelle
# 2                  CC3045                 STATION HEVIE  CODO  Ancien gérant
# 3                  CC6791  STATION SURU-LERE EX SONACOP  CODO  Fonctionnelle
# 4                  CC6139  STATION SURU-LERE EX SONACOP  CODO  Ancien gérant
#
#   Code Station GROUPE TYPE
# 0       ST0001     STATION
# 1       ST0002     STATION
# 2       ST0003     STATION
# 3       ST0004     STATION
# ...

# %%
# Afficher les 5 premières lignes avec toutes les colonnes visibles
pd.set_option('display.max_columns', None)   # affiche toutes les colonnes
pd.set_option('display.width', None)         # pas de limite de largeur
pd.set_option('display.max_colwidth', 20)    # limite la largeur de chaque cellule

df_clean.head()
# Out:
#   Date comptabilisation N° article N° origine N° contact origine  \
# 0           2017-02-03       A0001      C0437                NaN
# 1           2017-02-03       A0002      C0437                NaN
# 2           2017-02-03       A0001      C0001                NaN
# 3           2017-02-03       A0002      C0001                NaN
# 6           2017-02-03       A0001      C0126                NaN
#
#    Quantité facturée Code Produit     Type document           NOM CLIENT  \
# 0             4000.0   PROD-BLANC  Expédition vente  BENIN DIEU EST F...
# 1             4000.0   PROD-BLANC  Expédition vente  BENIN DIEU EST F...
# 2             3000.0   PROD-BLANC  Expédition vente  AGENCE DE TRAVAU...
# 3            30000.0   PROD-BLANC  Expédition vente  AGENCE DE TRAVAU...
# 6             6000.0   PROD-BLANC  Expédition vente  COMPTOIR AFRICAI...
#
#        Nom sous compte  TYPE         STATUT Code Station GROUPE TYPE
# ...

# %%
## ÉTAPE 5.4 : SUPPRESSION DES LIGNES SANS N° CONTACT ORIGINE
# Les lignes sans contact origine ne sont pas exploitables

# %%
print("Lignes avant :", df_clean.shape[0])

# Suppression des lignes où N° contact origine est vide
df_clean = df_clean.dropna(subset=["N° contact origine"])

print("Lignes après :", df_clean.shape[0])
print("Lignes supprimées :", df_clean.shape[0] - df_clean.shape[0])
print()

# Vérification
print("Valeurs manquantes restantes :")
print(df_clean.isnull().sum())
# Out:
# Lignes avant : 60020
# Lignes après : 60020
# Lignes supprimées : 0
#
# Valeurs manquantes restantes :
# Date comptabilisation    0
# N° article               0
# N° origine               0
# N° contact origine       0
# Quantité facturée        0
# Code Produit             0
# Type document            0
# NOM CLIENT               0
# Nom sous compte          0
# TYPE                     0
# STATUT                   0
# Code Station             0
# GROUPE TYPE              0
# dtype: int64
